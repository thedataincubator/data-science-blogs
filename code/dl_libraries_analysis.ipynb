# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
fields = ['toolkit','forks','stars','so_tag_counts','so_question_count','search_results', 'growth_rate']
DF = pd.read_csv('../output/deep_learning_data.csv', usecols=fields)

# %%
DF.fillna(0, inplace=True)

# %%
#scale the values, such that for each metric: mean = 0 and std = 1
metrics = ['forks','stars','so_tag_counts','so_question_count','search_results', 'growth_rate']
scaled_DF = pd.DataFrame(columns=metrics)

for metric in metrics:
    mean = DF[metric].mean()
    std = DF[metric].std()
    scaled_DF[metric] = DF[metric].apply(lambda x: (x-mean)/std)

scaled_DF['toolkit']= DF['toolkit']

# %%
#merge forks and stars to one GitHub metric, Tags and Questions to Stack Overflow
final_DF = pd.DataFrame(columns=['Toolkit', 'Rank', 'Overall', 'Github', 'Stack Overflow', 'Google Results'])
final_DF['Library'] = scaled_DF['toolkit']
final_DF['Github'] = scaled_DF[['forks', 'stars']].mean(axis=1)
final_DF['Stack Overflow'] = scaled_DF[['so_tag_counts', 'so_question_count']].mean(axis=1)
final_DF['Google Results'] = scaled_DF[['search_results', 'growth_rate']].mean(axis=1)
final_DF['Overall'] = final_DF[['Github','Stack Overflow','Google Results']].sum(axis=1)
final_DF['Rank'] = final_DF['Overall'].rank(ascending=0).astype(int)

# %%
final_DF.sort_values(['Overall'], axis=0, ascending=False, inplace=True)
final_DF = final_DF.reindex_axis(['Library','Rank','Overall','Github','Stack Overflow','Google Results'], axis=1)
final_DF.style.set_table_styles([
    {'selector': '.row_heading, .blank', 'props': [('display', 'none;')]}
])
# Out:
#         <style  type="text/css" >
#
#             #T_3ee8f60f_9954_11e7_8f93_0088653af0a2 .row_heading, .blank {
#
#                 display: none;;
#
#             }
#
#
#         </style>
#
#         <table id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Library
#
#                 <th class="col_heading level0 col1">Rank
#
#                 <th class="col_heading level0 col2">Overall
#
#                 <th class="col_heading level0 col3">Github
#
#                 <th class="col_heading level0 col4">Stack Overflow
#
#                 <th class="col_heading level0 col5">Google Results
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" class="row_heading level5 row0">
#                     19
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row0_col0" class="data row0 col0">
#                     tensorflow
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row0_col1" class="data row0 col1">
#                     1
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row0_col2" class="data row0 col2">
#                     10.8677
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row0_col3" class="data row0 col3">
#                     4.25283
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row0_col4" class="data row0 col4">
#                     4.37191
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row0_col5" class="data row0 col5">
#                     2.24294
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" class="row_heading level5 row1">
#                     9
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row1_col0" class="data row1 col0">
#                     keras
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row1_col1" class="data row1 col1">
#                     2
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row1_col2" class="data row1 col2">
#                     1.92769
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row1_col3" class="data row1 col3">
#                     0.613405
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row1_col4" class="data row1 col4">
#                     0.830444
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row1_col5" class="data row1 col5">
#                     0.483837
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" class="row_heading level5 row2">
#                     2
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row2_col0" class="data row2 col0">
#                     caffe
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row2_col1" class="data row2 col1">
#                     3
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row2_col2" class="data row2 col2">
#                     1.85537
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row2_col3" class="data row2 col3">
#                     1.00172
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row2_col4" class="data row2 col4">
#                     0.301598
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row2_col5" class="data row2 col5">
#                     0.552045
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" class="row_heading level5 row3">
#                     21
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row3_col0" class="data row3 col0">
#                     theano
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row3_col1" class="data row3 col1">
#                     4
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row3_col2" class="data row3 col2">
#                     0.757142
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row3_col3" class="data row3 col3">
#                     -0.156657
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row3_col4" class="data row3 col4">
#                     0.361637
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row3_col5" class="data row3 col5">
#                     0.552162
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" class="row_heading level5 row4">
#                     17
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row4_col0" class="data row4 col0">
#                     pytorch
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row4_col1" class="data row4 col1">
#                     5
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row4_col2" class="data row4 col2">
#                     0.481419
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row4_col3" class="data row4 col3">
#                     -0.198079
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row4_col4" class="data row4 col4">
#                     -0.30226
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row4_col5" class="data row4 col5">
#                     0.981758
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" class="row_heading level5 row5">
#                     18
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row5_col0" class="data row5 col0">
#                     sonnet
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row5_col1" class="data row5 col1">
#                     6
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row5_col2" class="data row5 col2">
#                     0.427866
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row5_col3" class="data row5 col3">
#                     -0.326075
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row5_col4" class="data row5 col4">
#                     -0.361634
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row5_col5" class="data row5 col5">
#                     1.11557
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2" class="row_heading level5 row6">
#                     12
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row6_col0" class="data row6 col0">
#                     mxnet
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row6_col1" class="data row6 col1">
#                     7
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row6_col2" class="data row6 col2">
#                     0.0987997
#
#                 <td id="T_3ee8f60f_9954_11e7_8f93_0088653af0a2row6_col3" class="data row6 col3">
#                     0.121327

# %%
final_DF.to_csv('../output/DL_libraries_final_Rankings.csv', index = False)
