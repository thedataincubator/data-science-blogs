# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
fields = ['toolkit','forks','stars','so_tag_counts','so_question_count','search_results']
DF = pd.read_csv('../output/deep_learning_data.csv', usecols=fields)

# %%
DF.fillna(0, inplace=True)

# %%
#scale the values, such that for each metric: mean = 0 and std = 1
metrics = ['forks','stars','so_tag_counts','so_question_count','search_results']
scaled_DF = pd.DataFrame(columns=metrics)

for metric in metrics:
    mean = DF[metric].mean()
    std = DF[metric].std()
    scaled_DF[metric] = DF[metric].apply(lambda x: (x-mean)/std)

scaled_DF['toolkit']= DF['toolkit']

# %%
#merge forks and stars to one GitHub metric, Tags and Questions to Stack Overflow
final_DF = pd.DataFrame(columns=['Toolkit', 'Rank', 'Overall', 'Github', 'Stack Overflow', 'Search Results'])
final_DF['Library'] = scaled_DF['toolkit']
final_DF['Github'] = scaled_DF[['forks', 'stars']].mean(axis=1)
final_DF['Stack Overflow'] = scaled_DF[['so_tag_counts', 'so_question_count']].mean(axis=1)
final_DF['Search Results'] = scaled_DF['search_results']
final_DF['Overall'] = final_DF[['Github','Stack Overflow','Search Results']].sum(axis=1)
final_DF['Rank'] = final_DF['Overall'].rank(ascending=0).astype(int)

# %%
final_DF.sort_values(['Overall'], axis=0, ascending=False, inplace=True)
final_DF = final_DF.reindex_axis(['Library','Rank','Overall','Github','Stack Overflow','Search Results'], axis=1)
final_DF.style.set_table_styles([
    {'selector': '.row_heading, .blank', 'props': [('display', 'none;')]}
])
# Out:
#         <style  type="text/css" >
#
#             #T_1fdffbf0_9414_11e7_aacd_0088653af0a2 .row_heading, .blank {
#
#                 display: none;;
#
#             }
#
#
#         </style>
#
#         <table id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Library
#
#                 <th class="col_heading level0 col1">Rank
#
#                 <th class="col_heading level0 col2">Overall
#
#                 <th class="col_heading level0 col3">Github
#
#                 <th class="col_heading level0 col4">Stack Overflow
#
#                 <th class="col_heading level0 col5">Search Results
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" class="row_heading level5 row0">
#                     19
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row0_col0" class="data row0 col0">
#                     tensorflow
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row0_col1" class="data row0 col1">
#                     1
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row0_col2" class="data row0 col2">
#                     12.8424
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row0_col3" class="data row0 col3">
#                     4.2515
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row0_col4" class="data row0 col4">
#                     4.37031
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row0_col5" class="data row0 col5">
#                     4.22063
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" class="row_heading level5 row1">
#                     2
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row1_col0" class="data row1 col0">
#                     caffe
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row1_col1" class="data row1 col1">
#                     2
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row1_col2" class="data row1 col2">
#                     2.2919
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row1_col3" class="data row1 col3">
#                     1.0065
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row1_col4" class="data row1 col4">
#                     0.30842
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row1_col5" class="data row1 col5">
#                     0.976976
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" class="row_heading level5 row2">
#                     9
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row2_col0" class="data row2 col0">
#                     keras
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row2_col1" class="data row2 col1">
#                     3
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row2_col2" class="data row2 col2">
#                     2.01751
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row2_col3" class="data row2 col3">
#                     0.613098
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row2_col4" class="data row2 col4">
#                     0.826883
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row2_col5" class="data row2 col5">
#                     0.577527
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" class="row_heading level5 row3">
#                     21
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row3_col0" class="data row3 col0">
#                     theano
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row3_col1" class="data row3 col1">
#                     4
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row3_col2" class="data row3 col2">
#                     0.677579
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row3_col3" class="data row3 col3">
#                     -0.154865
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row3_col4" class="data row3 col4">
#                     0.369046
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row3_col5" class="data row3 col5">
#                     0.463398
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" class="row_heading level5 row4">
#                     22
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row4_col0" class="data row4 col0">
#                     torch
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row4_col1" class="data row4 col1">
#                     5
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row4_col2" class="data row4 col2">
#                     0.023496
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row4_col3" class="data row4 col3">
#                     -0.151437
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row4_col4" class="data row4 col4">
#                     -0.00314373
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row4_col5" class="data row4 col5">
#                     0.178077
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" class="row_heading level5 row5">
#                     12
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row5_col0" class="data row5 col0">
#                     mxnet
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row5_col1" class="data row5 col1">
#                     6
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row5_col2" class="data row5 col2">
#                     -0.0711074
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row5_col3" class="data row5 col3">
#                     0.121557
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row5_col4" class="data row5 col4">
#                     -0.30767
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row5_col5" class="data row5 col5">
#                     0.115006
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2" class="row_heading level5 row6">
#                     5
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row6_col0" class="data row6 col0">
#                     cntk
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row6_col1" class="data row6 col1">
#                     7
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row6_col2" class="data row6 col2">
#                     -0.422835
#
#                 <td id="T_1fdffbf0_9414_11e7_aacd_0088653af0a2row6_col3" class="data row6 col3">
#                     0.0974149

# %%
final_DF.to_csv('../output/DL_libraries_final_Rankings.csv', index = False)
