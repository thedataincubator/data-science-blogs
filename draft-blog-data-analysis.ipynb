# %% [markdown]
# # How to identify "top R packages for Machine Learning"

# %% [markdown]
# 1. get a list of R packages for ML
# 1. use this list to get metrics from SO, github
# 1. use the metrics to rank the package list

# %% [markdown]
# # Load stuff

# %%
import pandas as pd

from code import utils as ut
from code import get_stack_overflow_data as gsod

# %% [markdown]
# # Get a list of R packages for ML

# %% [markdown]
# From the ["CRAN Task View: Machine Learning & Statistical Learning"](https://cran.r-project.org/web/views/MachineLearning.html)

# %%
package_list = ut.read_package_txt("package-list-from-cran-task-view.txt")

# %%
len(package_list)
# Out:
# 87

# %% [markdown]
# Here is a list of R packages used for machine learning:

# %%
print package_list
# Out:
# ['ahaz', 'arules', 'BayesTree', 'biglasso', 'bigRR', 'bmrm', 'Boruta', 'bst', 'C50', 'caret', 'CORElearn', 'CoxBoost', 'Cubist', 'e1071', 'earth', 'elasticnet', 'ElemStatLearn', 'evclass', 'evtree', 'FCNN4R', 'frbs', 'GAMBoost', 'gamboostLSS', 'gbm', 'glmnet', 'glmpath', 'GMMBoost', 'gmum.r', 'grplasso', 'grpreg', 'h2o', 'hda', 'hdi', 'hdm', 'ipred', 'kernlab', 'klaR', 'lars', 'lasso2', 'LiblineaR', 'LogicForest', 'LogicReg', 'maptree', 'mboost', 'mlr', 'ncvreg', 'nnet', 'oblique.tree', 'OneR', 'pamr', 'party', 'partykit', 'penalized', 'penalizedLDA', 'penalizedSVM', 'quantregForest', 'randomForest', 'randomForestSRC', 'ranger', 'rattle', 'Rborist', 'rda', 'rdetools', 'REEMtree', 'relaxo', 'rgenoud', 'rgp', 'Rmalschains', 'rminer', 'rnn', 'ROCR', 'RoughSets', 'rpart', 'RPMM', 'RSNNS', 'RWeka', 'RXshrink', 'sda', 'SIS', 'spa', 'stabs', 'SuperLearner', 'svmpath', 'tgp', 'tree', 'varSelRF', 'vcrpart']

# %% [markdown]
# # Get usage statistics on the ML packages

# %%
tag_counts = gsod.get_tag_counts(package_list)

# %%
question_body_counts = { item: gsod.get_body_count(item) for item in package_list}

# %%
tag = 'r'
question_body_counts_r = { item: gsod.get_body_count(item, tag=tag) for item in package_list}

# %%
def count_dict_to_pd(mydict, kind):
    df = pd.DataFrame.from_dict(mydict, orient='index')
    df.reset_index(inplace=True)
    df.columns = [['name', 'count']]
    df['kind'] = kind
    df.sort_values(by='count', inplace=True, ascending=False)
    return df

# %% [markdown]
# ## TAG counts on SO

# %%
df_tag = pd.DataFrame(tag_counts)
# filter to remove synonyms, which SO seems to add to return
df_tag = df_tag[df_tag['name'].isin(package_list)]
df_tag['kind'] = 'tag'
df_tag['rank'] = df_tag['count'].rank(ascending=False)
df_tag = df_tag[['name', 'count', 'rank', 'kind']]

# %%
df_tag.head(20)
# Out:
#        name  count  rank kind
# 0      tree  10536   1.0  tag
# 3     caret    559   2.0  tag
# 4       h2o    261   3.0  tag
# 5     rpart    226   4.0  tag
# 6    glmnet    193   5.0  tag
# 7    arules    175   6.0  tag
# 8       gbm    132   7.0  tag
# 9     party    115   8.0  tag
# 10     nnet     83   9.0  tag
# 12  kernlab     62  10.0  tag
# 13      rda     43  11.0  tag
# 15      mlr     30  12.0  tag
# 16   rattle     28  13.0  tag
# 17     lars     16  14.0  tag
# 19      sda      7  15.0  tag
# 20      rgp      2  16.0  tag

# %% [markdown]
# ## Question body counts on SO

# %%
df_body = count_dict_to_pd(question_body_counts, kind="body")
df_body['rank'] = df_body['count'].rank(ascending=False)

df_body.head(20)
# Out:
#             name    count  kind  rank
# 22          OneR  2541420  body   1.0
# 62          tree   123352  body   2.0
# 80         party    74708  body   3.0
# 50         caret    12829  body   4.0
# 2          earth    10916  body   5.0
# 74           spa     6275  body   6.0
# 81           bst     4009  body   7.0
# 55           sda     2331  body   8.0
# 43         stabs     1533  body   9.0
# 76  randomForest      873  body  10.0
# 23          lars      779  body  11.0
# 9            rnn      702  body  12.0
# 0            SIS      668  body  13.0
# 13         rpart      544  body  14.0
# 85           h2o      516  body  15.0
# 34        ranger      490  body  16.0
# 49     penalized      447  body  17.0
# 38           rda      414  body  18.0
# 24          nnet      412  body  19.0
# 25         e1071      399  body  20.0

# %% [markdown]
# ## Question body + 'R' tag, on SO

# %%
df_body_r = count_dict_to_pd(question_body_counts_r, kind="body_r_tag")
df_body_r['rank'] = df_body_r['count'].rank(ascending=False)


df_body_r.head(20)
# Out:
#             name  count        kind  rank
# 22          OneR  37941  body_r_tag   1.0
# 62          tree   1883  body_r_tag   2.0
# 50         caret   1066  body_r_tag   3.0
# 76  randomForest    639  body_r_tag   4.0
# 13         rpart    513  body_r_tag   5.0
# 80         party    433  body_r_tag   6.0
# 25         e1071    376  body_r_tag   7.0
# 83        glmnet    280  body_r_tag   8.0
# 24          nnet    279  body_r_tag   9.0
# 36        arules    248  body_r_tag  10.0
# 14           gbm    241  body_r_tag  11.5
# 38           rda    241  body_r_tag  11.5
# 2          earth    181  body_r_tag  13.0
# 85           h2o    180  body_r_tag  14.0
# 46         RWeka    169  body_r_tag  15.0
# 77          ROCR    133  body_r_tag  16.0
# 65       kernlab    126  body_r_tag  17.0
# 70        rattle     86  body_r_tag  18.0
# 81           bst     78  body_r_tag  19.0
# 63           mlr     57  body_r_tag  20.0

# %% [markdown]
# ## CONCAT

# %%
df_concat = pd.concat([df_tag, df_body_r, df_body])
df_concat['rank'] = df_concat['rank'].astype(object)

# %%
df_pivot = df_concat.pivot(index='name', columns='kind', values='rank')
#df_pivot.reset_index(inplace=True)
df_pivot.sort_values(by='body_r_tag', inplace=True)
df_pivot.reset_index(inplace=True)
df_pivot = df_pivot[['name', 'body_r_tag', 'tag', 'body']]

# %% [markdown]
# ## Stack overflow rankings
#
# Ranks based on 3 types of Stack searches are below. "OneR" has "none" for tag due to SO search API considering it a typo. Its "body" results are therefore also unreliable.

# %%
df_pivot.head(20)
# Out:
# kind          name body_r_tag   tag body
# 0             OneR          1  None    1
# 1             tree          2     1    2
# 2            caret          3     2    4
# 3     randomForest          4  None   10
# 4            rpart          5     4   14
# 5            party          6     8    3
# 6            e1071          7  None   20
# 7           glmnet          8     5   22
# 8             nnet          9     9   19
# 9           arules         10     6   23
# 10             gbm       11.5     7   21
# 11             rda       11.5    11   18
# 12           earth         13  None    5
# 13             h2o         14     3   15
# 14           RWeka         15  None   27
# 15            ROCR         16  None   29
# 16         kernlab         17    10   30
# 17          rattle         18    13   26
# 18             bst         19  None    7
# 19             mlr         20    12   32

# %% [markdown]
# # Visualize this

# %%
from bokeh.io import output_notebook, show
from bokeh.charts import Bar
from bokeh.charts.attributes import cat

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6fb089a1-31fc-4fc5-95cb-a0768e54b40e">Loading BokehJS ...</span>
#     </div>

# %%
df = df_merged.sort_values('count', ascending=False)

# %%
df = df.query("kind=='tag'")
df = df.head(20)

# %%
df
# Out:
#                        name  count kind
# 0                      tree  10530  tag
# 1        binary-search-tree   3219  tag
# 2   single-page-application   2353  tag
# 3                     caret    556  tag
# 4                       h2o    261  tag
# 5                     rpart    226  tag
# 6                    glmnet    192  tag
# 7                    arules    174  tag
# 8                       gbm    132  tag
# 9                     party    115  tag
# 10                     nnet     83  tag
# 11                liblinear     63  tag
# 12                  kernlab     62  tag
# 13                      rda     43  tag
# 14                    rweka     40  tag
# 15                      mlr     30  tag
# 16                   rattle     28  tag
# 17                     lars     16  tag
# 18                      sis     13  tag
# 19                      sda      7  tag

# %%
p = Bar(df, label=cat('name', sort=False), values='count', group='kind',
        title="PKGS FTW!", legend='top_right')

show(p)
# Out:
#     <div class="plotdiv" id="5bfac19f-edef-4496-996f-5b48731dd8ad"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5bfac19f-edef-4496-996f-5b48731dd8ad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5bfac19f-edef-4496-996f-5b48731dd8ad' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5644cce2-852e-4c17-8a71-089ab49acc29":{"roots":{"references":[{"attributes":{"data_source":{"id":"4ba16e77-0d0e-4f81-9c4d-c33cdbf3a81c","type":"ColumnDataSource"},"glyph":{"id":"da7b0dea-4d16-4cf7-9da1-cfd0ad761490","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5d47f919-5edc-42df-a5a6-7d87e4b987fe","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"kind":"in_question_body_r","name":"h2o"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[179.0],"kind":["in_question_body_r"],"line_alpha":[1.0],"line_color":["white"],"name":["h2o"],"width":[0.2],"x":["h2o:0.75"],"y":[89.5]}},"id":"8d075b8e-6d13-42ee-ac5b-16e2309ce356","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f8e38a53-4d0b-4721-8166-f54818de514b","type":"ColumnDataSource"},"glyph":{"id":"8c09df14-42f2-4724-addf-d90588cd87d1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"05787326-0740-4c7d-949c-607c90d9c4b6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"079cebf6-2b8a-41cb-8321-9c5dc655faea","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1442ae47-b588-4abc-9a35-8bd6e5f26e7a","type":"Rect"},{"attributes":{"data_source":{"id":"4066f40b-8988-46a5-a15a-d1a03f237b92","type":"ColumnDataSource"},"glyph":{"id":"b4d6c7cd-f536-4104-b940-71ca023c842e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"361e90a2-2c21-4fb5-8353-b38b67572bf7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"4a4875da-3cc2-42da-83d2-95574b69a4a3","type":"ColumnDataSource"},"glyph":{"id":"ad10be9b-7a39-470d-a6a0-b39eb9dc1a38","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2eac7af9-09bd-4ebd-8b47-b0b007ce63ba","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0a2ccb20-1e9e-4b2b-bb1e-d3424225ca2c","type":"ColumnDataSource"},"glyph":{"id":"d1e9e0da-84b5-4df4-a1dd-78460859675c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"18656966-1ccc-4a17-ab99-53215b37c61d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"2aa0022f-9be0-4ad0-af38-550116eab00e","type":"ColumnDataSource"},"glyph":{"id":"10c44966-f585-4842-9e21-d66921292ff3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"67a6f9e3-b646-446c-b712-77161d17f790","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"kind":"in_question_body_r","name":"h2o"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[179.0],"kind":["in_question_body_r"],"line_alpha":[1.0],"line_color":["white"],"name":["h2o"],"width":[0.2],"x":["h2o:0.666666666667"],"y":[89.5]}},"id":"80e73ba6-557e-4ae9-908b-a64c6949ddb9","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"615f9995-797c-4e8c-a54a-c7342109317b","type":"ColumnDataSource"},"glyph":{"id":"62dcb5e2-f0da-4862-9b42-a25e83de3b30","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f82dd8ea-e310-45b4-b194-2af2baeec775","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1476107a-5a54-4c58-b4a1-b9ec31780fcf","type":"ColumnDataSource"},"glyph":{"id":"2e2633e1-ff18-4647-a013-329283786b8e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c039aa2f-81ed-4756-b8cc-a6 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[57]</strong>&gt;</code></p>
